# %%
# %pip install google-cloud-aiplatform
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fde0a4372b0>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /simple/google-cloud-aiplatform/
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import vertexai
from vertexai.generative_models import GenerativeModel
# Out:
# /Users/petermousses/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
PROJECT='llms-441517'
LOCATION='us-central1'

MODEL_NAME='gemini-1.5-pro'

START_SEQUENCE='Step-by-step solution:\n'
END_SEQUENCE='Final Answer:\n'

PUZZLE_ROOT='./train'
REASONING_ROOT='./reasonings'

# %%
SYSTEM_PROMPT="""## View in plaintext
Iterative meta-token generation
### Prompt
Task Overview:
You are annotating a given chain of reasoning with meta-tokens. You will be provided with a description of the meta-tokens and an explanation on how they should be used. Given the previous steps as well as the immediate next step, you will generate and use the meta-tokens to arrive at that next step from the previous ones. You will also be provided the answer to ensure your generation is accurate, but you should not reference it at all. An annotation starts with the meta-token, followed by your usage of the token. Do not conclude meta-tokens with the same one and a slash, only by switching to a different meta-token.

Meta-tokens:
<recall> - This token is used to look over the context and pull out the information that will be immediately relevant to figuring out the next part.
<think> - This token is used to do internal reasoning, separately from normal discussion.
<generate> - The standard mode, used to switch back to normal response. Anything after this token is displayed to the user.

Usage Example:
```
problem statement
...
[relevant info]
...
previous line of reasoning
<recall>[relevant info] to be used in the next conclusion
<think>internal reasoning for the next conclusion
<generate>line of reasoning
```

For instance, if the text was:
```
Clues:
x. Clue

Chain of reasoning:
previous reasoning
next line of reasoning using clue x
```
Then your output would only be:
```
<recall>x. Clue
<think>How you arrive at the next line of reasoning based on the past and the recalled info
<generate>next line of reasoning
```

Problem:
```
Using only the clues below, match the prices to the options from customers and orders. Remember, as with all grid-based logic puzzles, no option in any category will ever be used more than once.

prices : $3.30, $3.40, $3.50, $3.60.
customers : Austin, Charlie, Eduardo, Ira.
orders : cappuccino, eggnog latte, iced americano, mocha.
Clues:
1. The coffee ordered by Austin cost 10 cents less than the eggnog latte.
2. The coffee Charlie ordered cost $3.30.
3. The eggnog latte was either the beverage Charlie ordered or the beverage ordered by Eduardo.
4. Of the coffee that cost $3.60 and the coffee Austin ordered, one was the mocha and the other was the cappuccino.
5. The cappuccino cost somewhat more than the eggnog latte.

Fill the following table to show your final answer.
$3.30 | correct option from customers | correct option from orders
$3.40 | correct option from customers | correct option from orders
$3.50 | correct option from customers | correct option from orders
$3.60 | correct option from customers | correct option from orders
```

Chain of reasoning:
```
<recall>Clue #2: The coffee Charlie ordered cost $3.30.
<think>From Clue #2, we know that Charlie ordered a coffee for $3.30. We need to determine which coffee this is. 
<generate>We can immediately place Charlie and $3.30 in the table.

Next Line of Reasoning: Clue #3: If eggnog latte is either Charlie or Eduardo, and Charlie and Eduardo are in the same category, then eggnog latte does not equal Austin. In short, eggnog latte cannot equal Austin

Final Answer:
$3.30 | Charlie | iced americano
$3.40 | Austin | mocha
$3.50 | Eduardo | eggnog latte
$3.60 | Ira | cappuccino
```

Instructions:
Use the meta-tokens to arrive at the next line of reasoning and ONLY the next line of reasoning. Do not generate further lines of reasoning. Do not abbreviate. There may be steps that use multiple annotations or do not need annotations at all, that is up to you. Ensure each meta-token stays within its own domain; for instance, do not have reasoning in recall annotations, and vice versa.

"""

# %%
vertexai.init(
	project=PROJECT, # You can find it by clicking on the project dropdown in the top left.
	location=LOCATION
)

# %%
model = GenerativeModel(
	model_name=MODEL_NAME,
	# system_instruction=SYSTEM_PROMPT
)

# %%
def get_model_response(prompt):
	response = model.generate_content(prompt, stream=False)
	return response.text

def get_hints(puzzle):
	answer = puzzle['answer']
	return answer[
		(answer.index(START_SEQUENCE) + len(START_SEQUENCE))
		:
		(answer.index(END_SEQUENCE))
	]

def get_answer(puzzle):
	answer = puzzle['answer']
	return answer[
		(answer.index(END_SEQUENCE) + len(END_SEQUENCE))
		:
	]

def get_prompt(question, reasoning_so_far):
	return f"""## View in plaintext
Iterative meta-token generation
### Prompt
Task Overview:
You are annotating a given chain of reasoning with meta-tokens. You will be provided with a description of the meta-tokens and an explanation on how they should be used. Given the previous steps as well as the immediate next step, you will generate and use the meta-tokens to arrive at that next step from the previous ones. You will also be provided the answer to ensure your generation is accurate, but you should not reference it at all. An annotation starts with the meta-token, followed by your usage of the token. Do not conclude meta-tokens with the same one and a slash, only by switching to a different meta-token.

Meta-tokens:
<recall> - This token is used to look over the context and pull out the information that will be immediately relevant to figuring out the next part.
<think> - This token is used to do internal reasoning, separately from normal discussion.
<generate> - The standard mode, used to switch back to normal response. Anything after this token is displayed to the user.

Usage Example:
```
problem statement
...
[relevant info]
...
previous line of reasoning
<recall>[relevant info] to be used in the next conclusion
<think>internal reasoning for the next conclusion
<generate>line of reasoning
```

For instance, if the text was:
```
Clues:
x. Clue

Chain of reasoning:
previous reasoning
next line of reasoning using clue x
```
Then your output would only be:
```
<recall>x. Clue
<think>How you arrive at the next line of reasoning based on the past and the recalled info
<generate>next line of reasoning
```

Problem:
{question}

Chain of reasoning:
{reasoning_so_far}

Instructions:
Use the meta-tokens to arrive at the next line of reasoning and ONLY the next line of reasoning. Do not generate further lines of reasoning. Do not abbreviate. There may be steps that use multiple annotations or do not need annotations at all, that is up to you. Ensure each meta-token stays within its own domain; for instance, do not have reasoning in recall annotations, and vice versa.

"""

def separate_prompt_and_response(prompt, full_response):
	return full_response.replace(prompt, '').strip()

def reasoning_generation_step(question, reasoning_so_far):
	return get_model_response(get_prompt(question, reasoning_so_far))

def is_end_of_reasoning(response):
	return False#response.strip().lower().find('final answer:') > -1

def generate_reasoning_chain(puzzle):
	try:
		response = ''
		# previous_response = puzzle['question']
		while not is_end_of_reasoning(response):
			response += reasoning_generation_step(puzzle['question'], response)
			# print(separate_prompt_and_response(previous_response, response), end='\n----\n') # for debugging
			# previous_response = response
	except KeyboardInterrupt:
		pass # capture keyboard interrupt to save to file later on
	finally:
		return response
	
def generate_answer(puzzle, reasoning):
	return get_model_response(f"""
Generate the final answer for the following puzzle and the reasoning chain. Your response should ONLY include the final answer presented as a table and NOTHING ELSE.

{reasoning}
""")

# %%
file_name = '341'
with open(os.path.join(PUZZLE_ROOT, f'{file_name}.json'), 'r') as file:
	os.makedirs(os.path.join(REASONING_ROOT, file_name), exist_ok=True)
	puzzles = json.load(file)
	for sample in puzzles:
		id = sample['id']
		output_file_name = os.path.join(REASONING_ROOT, file_name, f'{id}_reasoning.txt')
		sample_chain = generate_reasoning_chain(sample)
		with open(output_file_name, 'w') as reasoning_file:
			json.dump(sample_chain, reasoning_file)
			print(f'Reasoning {id} saved to {output_file_name}')
# Out:
# Reasoning 318 saved to ./reasonings/341/318_reasoning.txt
# Reasoning 554 saved to ./reasonings/341/554_reasoning.txt
# Reasoning 757 saved to ./reasonings/341/757_reasoning.txt
# Reasoning 926 saved to ./reasonings/341/926_reasoning.txt
# Reasoning 336 saved to ./reasonings/341/336_reasoning.txt
# Reasoning 342 saved to ./reasonings/341/342_reasoning.txt
# Reasoning 934 saved to ./reasonings/341/934_reasoning.txt
# Reasoning 264 saved to ./reasonings/341/264_reasoning.txt
# Reasoning 241 saved to ./reasonings/341/241_reasoning.txt
# Reasoning 879 saved to ./reasonings/341/879_reasoning.txt
# Reasoning 894 saved to ./reasonings/341/894_reasoning.txt
# Reasoning 458 saved to ./reasonings/341/458_reasoning.txt
# Reasoning 198 saved to ./reasonings/341/198_reasoning.txt
# Reasoning 778 saved to ./reasonings/341/778_reasoning.txt
# Reasoning 753 saved to ./reasonings/341/753_reasoning.txt
# Reasoning 293 saved to ./reasonings/341/293_reasoning.txt
# Reasoning 932 saved to ./reasonings/341/932_reasoning.txt
# Reasoning 865 saved to ./reasonings/341/865_reasoning.txt
# Reasoning 414 saved to ./reasonings/341/414_reasoning.txt
# Reasoning 18 saved to ./reasonings/341/18_reasoning.txt
# Reasoning 289 saved to ./reasonings/341/289_reasoning.txt
# Reasoning 485 saved to ./reasonings/341/485_reasoning.txt
# Reasoning 848 saved to ./reasonings/341/848_reasoning.txt
# Reasoning 923 saved to ./reasonings/341/923_reasoning.txt
# Reasoning 396 saved to ./reasonings/341/396_reasoning.txt
# Reasoning 16 saved to ./reasonings/341/16_reasoning.txt
# Reasoning 1 saved to ./reasonings/341/1_reasoning.txt
# Reasoning 38 saved to ./reasonings/341/38_reasoning.txt
# Reasoning 211 saved to ./reasonings/341/211_reasoning.txt
# Reasoning 272 saved to ./reasonings/341/272_reasoning.txt
# Reasoning 503 saved to ./reasonings/341/503_reasoning.txt
# Reasoning 810 saved to ./reasonings/341/810_reasoning.txt
# Reasoning 755 saved to ./reasonings/341/755_reasoning.txt
# Reasoning 369 saved to ./reasonings/341/369_reasoning.txt
# Reasoning 536 saved to ./reasonings/341/536_reasoning.txt
# Reasoning 508 saved to ./reasonings/341/508_reasoning.txt
# Reasoning 353 saved to ./reasonings/341/353_reasoning.txt
# Reasoning 585 saved to ./reasonings/341/585_reasoning.txt
# Reasoning 221 saved to ./reasonings/341/221_reasoning.txt
# Reasoning 927 saved to ./reasonings/341/927_reasoning.txt
# Reasoning 85 saved to ./reasonings/341/85_reasoning.txt
# Reasoning 426 saved to ./reasonings/341/426_reasoning.txt
# Reasoning 150 saved to ./reasonings/341/150_reasoning.txt
# Reasoning 361 saved to ./reasonings/341/361_reasoning.txt
# Reasoning 528 saved to ./reasonings/341/528_reasoning.txt
# Reasoning 24 saved to ./reasonings/341/24_reasoning.txt
# Reasoning 842 saved to ./reasonings/341/842_reasoning.txt
# Reasoning 355 saved to ./reasonings/341/355_reasoning.txt
# Reasoning 398 saved to ./reasonings/341/398_reasoning.txt
# Reasoning 360 saved to ./reasonings/341/360_reasoning.txt
# Reasoning 34 saved to ./reasonings/341/34_reasoning.txt
# Reasoning 622 saved to ./reasonings/341/622_reasoning.txt
# Reasoning 262 saved to ./reasonings/341/262_reasoning.txt
# Reasoning 845 saved to ./reasonings/341/845_reasoning.txt
# Reasoning 513 saved to ./reasonings/341/513_reasoning.txt
# Reasoning 436 saved to ./reasonings/341/436_reasoning.txt
# Reasoning 657 saved to ./reasonings/341/657_reasoning.txt
# Reasoning 912 saved to ./reasonings/341/912_reasoning.txt
# Reasoning 922 saved to ./reasonings/341/922_reasoning.txt
# Reasoning 851 saved to ./reasonings/341/851_reasoning.txt
# Reasoning 589 saved to ./reasonings/341/589_reasoning.txt
# Reasoning 670 saved to ./reasonings/341/670_reasoning.txt
# Reasoning 386 saved to ./reasonings/341/386_reasoning.txt
# Reasoning 907 saved to ./reasonings/341/907_reasoning.txt
# Reasoning 384 saved to ./reasonings/341/384_reasoning.txt
# Reasoning 668 saved to ./reasonings/341/668_reasoning.txt
# Reasoning 451 saved to ./reasonings/341/451_reasoning.txt
# Reasoning 612 saved to ./reasonings/341/612_reasoning.txt
# Reasoning 333 saved to ./reasonings/341/333_reasoning.txt
# Reasoning 28 saved to ./reasonings/341/28_reasoning.txt
# Reasoning 364 saved to ./reasonings/341/364_reasoning.txt
# Reasoning 803 saved to ./reasonings/341/803_reasoning.txt
# Reasoning 330 saved to ./reasonings/341/330_reasoning.txt
# Reasoning 229 saved to ./reasonings/341/229_reasoning.txt
# Reasoning 653 saved to ./reasonings/341/653_reasoning.txt
# Reasoning 596 saved to ./reasonings/341/596_reasoning.txt
# Reasoning 467 saved to ./reasonings/341/467_reasoning.txt
# Reasoning 149 saved to ./reasonings/341/149_reasoning.txt
# Reasoning 649 saved to ./reasonings/341/649_reasoning.txt
# Reasoning 177 saved to ./reasonings/341/177_reasoning.txt
# Reasoning 561 saved to ./reasonings/341/561_reasoning.txt
# Reasoning 480 saved to ./reasonings/341/480_reasoning.txt
# Reasoning 748 saved to ./reasonings/341/748_reasoning.txt
# Reasoning 247 saved to ./reasonings/341/247_reasoning.txt
# Reasoning 700 saved to ./reasonings/341/700_reasoning.txt
# Reasoning 311 saved to ./reasonings/341/311_reasoning.txt
# Reasoning 287 saved to ./reasonings/341/287_reasoning.txt
# Reasoning 905 saved to ./reasonings/341/905_reasoning.txt
# Reasoning 820 saved to ./reasonings/341/820_reasoning.txt
# Reasoning 688 saved to ./reasonings/341/688_reasoning.txt
# Reasoning 308 saved to ./reasonings/341/308_reasoning.txt
# Reasoning 493 saved to ./reasonings/341/493_reasoning.txt
# Reasoning 174 saved to ./reasonings/341/174_reasoning.txt
# Reasoning 66 saved to ./reasonings/341/66_reasoning.txt
# Reasoning 475 saved to ./reasonings/341/475_reasoning.txt
# Reasoning 350 saved to ./reasonings/341/350_reasoning.txt
# Reasoning 354 saved to ./reasonings/341/354_reasoning.txt
# Reasoning 903 saved to ./reasonings/341/903_reasoning.txt
# Reasoning 783 saved to ./reasonings/341/783_reasoning.txt
# Reasoning 808 saved to ./reasonings/341/808_reasoning.txt
# Reasoning 684 saved to ./reasonings/341/684_reasoning.txt
# Reasoning 358 saved to ./reasonings/341/358_reasoning.txt
# Reasoning 967 saved to ./reasonings/341/967_reasoning.txt
# Reasoning 568 saved to ./reasonings/341/568_reasoning.txt
# Reasoning 821 saved to ./reasonings/341/821_reasoning.txt
# Reasoning 372 saved to ./reasonings/341/372_reasoning.txt
# Reasoning 329 saved to ./reasonings/341/329_reasoning.txt
# Reasoning 835 saved to ./reasonings/341/835_reasoning.txt
# Reasoning 435 saved to ./reasonings/341/435_reasoning.txt
# Reasoning 620 saved to ./reasonings/341/620_reasoning.txt
# Reasoning 380 saved to ./reasonings/341/380_reasoning.txt
# Reasoning 189 saved to ./reasonings/341/189_reasoning.txt
# Reasoning 298 saved to ./reasonings/341/298_reasoning.txt
# Reasoning 251 saved to ./reasonings/341/251_reasoning.txt
# Reasoning 726 saved to ./reasonings/341/726_reasoning.txt
# Reasoning 804 saved to ./reasonings/341/804_reasoning.txt
# Reasoning 381 saved to ./reasonings/341/381_reasoning.txt
# Reasoning 424 saved to ./reasonings/341/424_reasoning.txt
# Reasoning 548 saved to ./reasonings/341/548_reasoning.txt
# Reasoning 676 saved to ./reasonings/341/676_reasoning.txt
# Reasoning 461 saved to ./reasonings/341/461_reasoning.txt
# Reasoning 800 saved to ./reasonings/341/800_reasoning.txt
# Reasoning 334 saved to ./reasonings/341/334_reasoning.txt
# Reasoning 92 saved to ./reasonings/341/92_reasoning.txt
# Reasoning 110 saved to ./reasonings/341/110_reasoning.txt
# Reasoning 200 saved to ./reasonings/341/200_reasoning.txt
# Reasoning 928 saved to ./reasonings/341/928_reasoning.txt
# Reasoning 979 saved to ./reasonings/341/979_reasoning.txt
# Reasoning 560 saved to ./reasonings/341/560_reasoning.txt
# Reasoning 974 saved to ./reasonings/341/974_reasoning.txt
# Reasoning 624 saved to ./reasonings/341/624_reasoning.txt
